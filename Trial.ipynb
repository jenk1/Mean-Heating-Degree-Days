# %%
import pandas as pd
import numpy as np

# %%
x = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|", names=(1, 2, 3, 4, 5, 6, 7, 8, "Conv"))

# %%
x
# Out:
#                                      1           2           3           4  \
# 0   Product: Daily Heating Degree Days         NaN         NaN         NaN
# 1    Regions: Regions::CensusDivisions         NaN         NaN         NaN
# 2                  Weights: Population         NaN         NaN         NaN
# 3                               Region  19810101.0  19810102.0  19810103.0
# 4                                    1        51.0        46.0        55.0
# 5                                    2        45.0        42.0        50.0
# 6                                    3        36.0        43.0        51.0
# 7                                    4        33.0        40.0        46.0
# 8                                    5        24.0        23.0        26.0
# 9                                    6        24.0        29.0        28.0
# 10                                   7        14.0        17.0        17.0
# ...

# %%
x = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-e636b2519c7d> in <module>()
# ----> 1 x = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|")
#
# ...

# %%
x = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|", )
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-b646d7c2bb8e> in <module>()
# ----> 1 x = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|", header=None)
#
# ...
