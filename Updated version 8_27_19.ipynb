# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline

# %% [markdown]
# Start data at 1981 and read it into a pandas dataframe. After looking it over I want to create a function where I can loop over the other years and add it to the dataframe.

# %%
x = pd.read_csv("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|", skiprows=[0,1,2])
# Below I am changing the region column as the index instead of the standard 0, 1, ... n
x = x.set_index('Region')

# %%
x.head()
# Out:
#         19810101  19810102  19810103  19810104  19810105  19810106  19810107  \
# Region
# 1             51        46        55        66        62        51        42
# 2             45        42        50        59        56        47        42
# 3             36        43        51        62        59        48        49
# 4             33        40        46        55        47        39        47
# 5             24        23        26        27        34        31        23
#
#         19810108  19810109  19810110  ...  19811222  19811223  19811224  \
# Region                                ...
# 1             51        58        53  ...        40        32        31
# 2             51        56        52  ...        38        25        28
# 3             57        55        57  ...        34        36        41
# 4             48        48        54  ...        36        44        44
# 5             30        31        31  ...        21         9        12
#
# ...

# %%
y = pd.read_csv("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1982/Population.Heating.txt", delimiter="|", skiprows=[0,1,2])
# Below I am changing the region column as the index instead of the standard 0, 1, ... n
y = y.set_index('Region')

# %%
y.head()
# Out:
#         19820101  19820102  19820103  19820104  19820105  19820106  19820107  \
# Region
# 1             36        36        45        32        27        37        33
# 2             30        35        39        26        27        34        30
# 3             40        44        34        32        39        37        47
# 4             55        46        48        51        47        53        63
# 5             16        17        18        12        17        18        10
#
#         19820108  19820109  19820110  ...  19821222  19821223  19821224  \
# Region                                ...
# 1             42        48        54  ...        37        38        34
# 2             41        45        55  ...        33        32        23
# 3             54        57        72  ...        34        23        15
# 4             56        61        75  ...        28        23        22
# 5             16        24        34  ...        22        17        11
#
# ...

# %%
result = pd.concat([x,y], axis=1)

# %%
result.head()
# Out:
#         19810101  19810102  19810103  19810104  19810105  19810106  19810107  \
# Region
# 1             51        46        55        66        62        51        42
# 2             45        42        50        59        56        47        42
# 3             36        43        51        62        59        48        49
# 4             33        40        46        55        47        39        47
# 5             24        23        26        27        34        31        23
#
#         19810108  19810109  19810110  ...  19821222  19821223  19821224  \
# Region                                ...
# 1             51        58        53  ...        37        38        34
# 2             51        56        52  ...        33        32        23
# 3             57        55        57  ...        34        23        15
# 4             48        48        54  ...        28        23        22
# 5             30        31        31  ...        22        17        11
#
# ...

# %%
z = pd.read_csv("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1984/Population.Heating.txt", delimiter="|", skiprows=[0,1,2])
# Below I am changing the region column as the index instead of the standard 0, 1, ... n
z = z.set_index('Region')

# %%
result = pd.concat([result, z], axis=1)

# %%
result.head()
# Out:
#         19810101  19810102  19810103  19810104  19810105  19810106  19810107  \
# Region
# 1             51        46        55        66        62        51        42
# 2             45        42        50        59        56        47        42
# 3             36        43        51        62        59        48        49
# 4             33        40        46        55        47        39        47
# 5             24        23        26        27        34        31        23
#
#         19810108  19810109  19810110  ...  19841222  19841223  19841224  \
# Region                                ...
# 1             51        58        53  ...        30        30        31
# 2             51        56        52  ...        23        28        29
# 3             57        55        57  ...        29        36        36
# 4             48        48        54  ...        41        41        48
# 5             30        31        31  ...         6        12        14
#
# ...

# %%
z.describe()
# Out:
#         19840101   19840102   19840103  19840104   19840105   19840106  \
# count  10.000000  10.000000  10.000000  10.00000  10.000000  10.000000
# mean   35.300000  32.000000  30.000000  26.50000  23.800000  23.600000
# std     9.580652   9.261629   8.313309   7.30677   7.330302   7.396696
# min    16.000000  16.000000  15.000000  13.00000  12.000000  10.000000
# 25%    30.250000  27.000000  24.250000  23.50000  20.750000  19.750000
# 50%    36.000000  32.000000  30.500000  27.00000  24.500000  24.000000
# 75%    43.500000  40.000000  37.000000  32.50000  29.750000  29.000000
# max    46.000000  43.000000  40.000000  35.00000  33.000000  34.000000
#
#         19840107   19840108  19840109   19840110  ...   19841222   19841223  \
# count  10.000000  10.000000   10.0000  10.000000  ...  10.000000  10.000000
# mean   26.000000  29.000000   28.8000  30.600000  ...  22.700000  25.700000
# std     9.092121  10.801234   11.8865  12.518431  ...  11.363196   9.944848
# ...

# %% [markdown]
# What I need to do is create a function that takes the dataframe and puts together all the years

# %%
def comb_data(start, end, df):
    for i in range(start, end+1):
        
        y = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/%d/Population.Heating.txt" %(i), delimiter="|", skiprows=[0,1,2])
        y = y.set_index('Region')
    
        df = pd.concat([df,y], axis=1)
