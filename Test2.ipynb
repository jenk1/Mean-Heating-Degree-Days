# %%
import pandas as pd
import numpy as np

# %%
x = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|", names=(1, 2, 3, 4, 5, 6, 7, 8, "Conv"))

# %%
x
# Out:
#                                      1           2           3           4  \
# 0   Product: Daily Heating Degree Days         NaN         NaN         NaN
# 1    Regions: Regions::CensusDivisions         NaN         NaN         NaN
# 2                  Weights: Population         NaN         NaN         NaN
# 3                               Region  19810101.0  19810102.0  19810103.0
# 4                                    1        51.0        46.0        55.0
# 5                                    2        45.0        42.0        50.0
# 6                                    3        36.0        43.0        51.0
# 7                                    4        33.0        40.0        46.0
# 8                                    5        24.0        23.0        26.0
# 9                                    6        24.0        29.0        28.0
# 10                                   7        14.0        17.0        17.0
# ...

# %%
x = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|", skiprows=[0,1,2])

# %%
x
# Out:
#   Region  19810101  19810102  19810103  19810104  19810105  19810106  \
# 0      1        51        46        55        66        62        51
# 1      2        45        42        50        59        56        47
# 2      3        36        43        51        62        59        48
# 3      4        33        40        46        55        47        39
# 4      5        24        23        26        27        34        31
# 5      6        24        29        28        30        42        36
# 6      7        14        17        17        18        22        18
# 7      8        22        22        23        23        24        26
# 8      9        14        16        14        15        14        15
# 9  CONUS        28        29        33        37        38        33
#
#    19810107  19810108  19810109    ...     19811222  19811223  19811224  \
# 0        42        51        58    ...           40        32        31
# ...

# %%
x = x.set_index('Region')

# %%
x
# Out:
#         19810101  19810102  19810103  19810104  19810105  19810106  19810107  \
# Region
# 1             51        46        55        66        62        51        42
# 2             45        42        50        59        56        47        42
# 3             36        43        51        62        59        48        49
# 4             33        40        46        55        47        39        47
# 5             24        23        26        27        34        31        23
# 6             24        29        28        30        42        36        32
# 7             14        17        17        18        22        18        19
# 8             22        22        23        23        24        26        26
# 9             14        16        14        15        14        15        17
# CONUS         28        29        33        37        38        33        31
#
#         19810108  19810109  19810110    ...     19811222  19811223  19811224  \
# ...

# %%
y = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1982/Population.Heating.txt", delimiter="|", skiprows=[0,1,2])

# %%
y = y.set_index('Region')

# %%
y
# Out:
#         19820101  19820102  19820103  19820104  19820105  19820106  19820107  \
# Region
# 1             36        36        45        32        27        37        33
# 2             30        35        39        26        27        34        30
# 3             40        44        34        32        39        37        47
# 4             55        46        48        51        47        53        63
# 5             16        17        18        12        17        18        10
# 6             22        24        15        13        26        19        16
# 7             17        12         7        15        16         8        15
# 8             28        35        39        36        31        36        43
# 9             22        25        28        26        24        27        30
# CONUS         27        29        28        25        27        28        29
#
#         19820108  19820109  19820110    ...     19821222  19821223  19821224  \
# ...

# %%
z = pd.concat([x,y], axis=1)

# %%
z
# Out:
#         19810101  19810102  19810103  19810104  19810105  19810106  19810107  \
# Region
# 1             51        46        55        66        62        51        42
# 2             45        42        50        59        56        47        42
# 3             36        43        51        62        59        48        49
# 4             33        40        46        55        47        39        47
# 5             24        23        26        27        34        31        23
# 6             24        29        28        30        42        36        32
# 7             14        17        17        18        22        18        19
# 8             22        22        23        23        24        26        26
# 9             14        16        14        15        14        15        17
# CONUS         28        29        33        37        38        33        31
#
#         19810108  19810109  19810110    ...     19821222  19821223  19821224  \
# ...
