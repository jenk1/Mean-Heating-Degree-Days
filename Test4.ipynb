# %%
import pandas as pd
import numpy as np

# %%
x = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/1981/Population.Heating.txt", delimiter="|", skiprows=[0,1,2])
x = x.set_index('Region')

# %%
x.head()
# Out:
#         19810101  19810102  19810103  19810104  19810105  19810106  19810107  \
# Region
# 1             51        46        55        66        62        51        42
# 2             45        42        50        59        56        47        42
# 3             36        43        51        62        59        48        49
# 4             33        40        46        55        47        39        47
# 5             24        23        26        27        34        31        23
#
#         19810108  19810109  19810110    ...     19811222  19811223  19811224  \
# Region                                  ...
# 1             51        58        53    ...           40        32        31
# 2             51        56        52    ...           38        25        28
# 3             57        55        57    ...           34        36        41
# 4             48        48        54    ...           36        44        44
# 5             30        31        31    ...           21         9        12
#
#         19811225  19811226  19811227  19811228  19811229  19811230  19811231
# Region
# 1             34        39        37        36        32        38        44
# 2             32        36        34        32        30        37        39
# 3             41        36        35        38        45        48        39
# 4             42        39        41        47        53        48        44
# 5             16        20        19        18        16        21        22
#
# [5 rows x 365 columns]

# %%
i = 1982
leapYears = []
while(i < 2018):
    y = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/%d/Population.Heating.txt" %(i), delimiter="|", skiprows=[0,1,2])
    y = y.set_index('Region')
    if(len(y.columns) > 365):
        leapYears.append(i)
    result = pd.concat([x,y], axis=1)
    x = result
    i += 1
# Out:
# ---------------------------------------------------------------------------
# error_perm                                Traceback (most recent call last)
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in retrfile(self, file, type)
#    2405                 cmd = 'RETR ' + file
# -> 2406                 conn, retrlen = self.ftp.ntransfercmd(cmd)
#    2407             except ftplib.error_perm as reason:
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in ntransfercmd(self, cmd, rest)
#     358         if self.passiveserver:
# --> 359             host, port = self.makepasv()
#     360             conn = socket.create_connection((host, port), self.timeout,
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in makepasv(self)
#     336         if self.af == socket.AF_INET:
# --> 337             host, port = parse227(self.sendcmd('PASV'))
#     338         else:
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in sendcmd(self, cmd)
#     272         self.putcmd(cmd)
# --> 273         return self.getresp()
#     274
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in getresp(self)
#     245         if c == '5':
# --> 246             raise error_perm(resp)
#     247         raise error_proto(resp)
#
# error_perm: 500 OOPS: vsf_sysutil_bind
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in ftp_open(self, req)
#    1540                     type = value.upper()
# -> 1541             fp, retrlen = fw.retrfile(file, type)
#    1542             headers = ""
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in retrfile(self, file, type)
#    2409                     raise URLError('ftp error: %r' % reason).with_traceback(
# -> 2410                         sys.exc_info()[2])
#    2411         if not conn:
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in retrfile(self, file, type)
#    2405                 cmd = 'RETR ' + file
# -> 2406                 conn, retrlen = self.ftp.ntransfercmd(cmd)
#    2407             except ftplib.error_perm as reason:
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in ntransfercmd(self, cmd, rest)
#     358         if self.passiveserver:
# --> 359             host, port = self.makepasv()
#     360             conn = socket.create_connection((host, port), self.timeout,
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in makepasv(self)
#     336         if self.af == socket.AF_INET:
# --> 337             host, port = parse227(self.sendcmd('PASV'))
#     338         else:
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in sendcmd(self, cmd)
#     272         self.putcmd(cmd)
# --> 273         return self.getresp()
#     274
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in getresp(self)
#     245         if c == '5':
# --> 246             raise error_perm(resp)
#     247         raise error_proto(resp)
#
# URLError: <urlopen error ftp error: error_perm('500 OOPS: vsf_sysutil_bind',)>
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-9-7889b5e04463> in <module>()
#       2 leapYears = []
#       3 while(i < 2018):
# ----> 4     y = pd.read_table("ftp://ftp.cpc.ncep.noaa.gov/htdocs/degree_days/weighted/daily_data/%d/Population.Heating.txt" %(i), delimiter="|", skiprows=[0,1,2])
#       5     y = y.set_index('Region')
#       6     if(len(y.columns) > 365):
#
# ~\Anaconda2\envs\TF_Env\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~\Anaconda2\envs\TF_Env\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     431     compression = _infer_compression(filepath_or_buffer, compression)
#     432     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 433         filepath_or_buffer, encoding, compression)
#     434     kwds['compression'] = compression
#     435
#
# ~\Anaconda2\envs\TF_Env\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     188
#     189     if _is_url(filepath_or_buffer):
# --> 190         req = _urlopen(filepath_or_buffer)
#     191         content_encoding = req.headers.get('Content-Encoding', None)
#     192         if content_encoding == 'gzip':
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in ftp_open(self, req)
#    1550         except ftplib.all_errors as exp:
#    1551             exc = URLError('ftp error: %r' % exp)
# -> 1552             raise exc.with_traceback(sys.exc_info()[2])
#    1553
#    1554     def connect_ftp(self, user, passwd, host, port, dirs, timeout):
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in ftp_open(self, req)
#    1539                    value in ('a', 'A', 'i', 'I', 'd', 'D'):
#    1540                     type = value.upper()
# -> 1541             fp, retrlen = fw.retrfile(file, type)
#    1542             headers = ""
#    1543             mtype = mimetypes.guess_type(req.full_url)[0]
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in retrfile(self, file, type)
#    2408                 if str(reason)[:3] != '550':
#    2409                     raise URLError('ftp error: %r' % reason).with_traceback(
# -> 2410                         sys.exc_info()[2])
#    2411         if not conn:
#    2412             # Set transfer mode to ASCII!
#
# ~\Anaconda2\envs\TF_Env\lib\urllib\request.py in retrfile(self, file, type)
#    2404             try:
#    2405                 cmd = 'RETR ' + file
# -> 2406                 conn, retrlen = self.ftp.ntransfercmd(cmd)
#    2407             except ftplib.error_perm as reason:
#    2408                 if str(reason)[:3] != '550':
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in ntransfercmd(self, cmd, rest)
#     357         size = None
#     358         if self.passiveserver:
# --> 359             host, port = self.makepasv()
#     360             conn = socket.create_connection((host, port), self.timeout,
#     361                                             source_address=self.source_address)
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in makepasv(self)
#     335     def makepasv(self):
#     336         if self.af == socket.AF_INET:
# --> 337             host, port = parse227(self.sendcmd('PASV'))
#     338         else:
#     339             host, port = parse229(self.sendcmd('EPSV'), self.sock.getpeername())
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in sendcmd(self, cmd)
#     271         '''Send a command and return the response.'''
#     272         self.putcmd(cmd)
# --> 273         return self.getresp()
#     274
#     275     def voidcmd(self, cmd):
#
# ~\Anaconda2\envs\TF_Env\lib\ftplib.py in getresp(self)
#     244             raise error_temp(resp)
#     245         if c == '5':
# --> 246             raise error_perm(resp)
#     247         raise error_proto(resp)
#     248
#
# URLError: <urlopen error ftp error: URLError("ftp error: error_perm('500 OOPS: vsf_sysutil_bind',)",)>

# %%
result
# Out:
#         19810101  19810102  19810103  19810104  19810105  19810106  19810107  \
# Region
# 1             51        46        55        66        62        51        42
# 2             45        42        50        59        56        47        42
# 3             36        43        51        62        59        48        49
# 4             33        40        46        55        47        39        47
# 5             24        23        26        27        34        31        23
# 6             24        29        28        30        42        36        32
# 7             14        17        17        18        22        18        19
# 8             22        22        23        23        24        26        26
# 9             14        16        14        15        14        15        17
# CONUS         28        29        33        37        38        33        31
#
#         19810108  19810109  19810110    ...     19851222  19851223  19851224  \
# Region                                  ...
# 1             51        58        53    ...           48        40        32
# 2             51        56        52    ...           47        38        29
# 3             57        55        57    ...           48        36        43
# 4             48        48        54    ...           37        33        48
# 5             30        31        31    ...           33        23        15
# 6             39        35        37    ...           35        23        25
# 7             20        18        18    ...           16        13        15
# 8             28        28        27    ...           29        29        30
# 9             18        17        16    ...           19        19        18
# CONUS         36        37        36    ...           34        27        26
#
#         19851225  19851226  19851227  19851228  19851229  19851230  19851231
# Region
# 1             33        49        48        40        44        42        38
# 2             36        51        44        38        40        40        37
# 3             59        57        45        50        49        47        39
# 4             60        46        42        47        45        40        38
# 5             21        39        31        23        21        24        23
# 6             39        47        34        29        31        32        26
# 7             27        29        20        18        18        15        11
# 8             31        31        32        32        31        28        29
# 9             17        19        21        21        18        16        17
# CONUS         34        40        34        32        31        30        27
#
# [10 rows x 26662 columns]

# %%
result.isnull().sum()
# Out:
# 19810101    0
# 19810102    0
# 19810103    0
# 19810104    0
# 19810105    0
# 19810106    0
# 19810107    0
# 19810108    0
# 19810109    0
# 19810110    0
# 19810111    0
# 19810112    0
# 19810113    0
# 19810114    0
# 19810115    0
# 19810116    0
# 19810117    0
# 19810118    0
# 19810119    0
# 19810120    0
# 19810121    0
# 19810122    0
# 19810123    0
# 19810124    0
# 19810125    0
# 19810126    0
# 19810127    0
# 19810128    0
# 19810129    0
# 19810130    0
#            ..
# 19851202    0
# 19851203    0
# 19851204    0
# 19851205    0
# 19851206    0
# 19851207    0
# 19851208    0
# 19851209    0
# 19851210    0
# 19851211    0
# 19851212    0
# 19851213    0
# 19851214    0
# 19851215    0
# 19851216    0
# 19851217    0
# 19851218    0
# 19851219    0
# 19851220    0
# 19851221    0
# 19851222    0
# 19851223    0
# 19851224    0
# 19851225    0
# 19851226    0
# 19851227    0
# 19851228    0
# 19851229    0
# 19851230    0
# 19851231    0
# Length: 26662, dtype: int64

# %%
leapYears
# Out:
# [1984]
